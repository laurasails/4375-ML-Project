# %%
import pandas as pd
import numpy as np

# use ISO-8859-1 encoding to read the CSV file due to special characters
df = pd.read_csv("Combined_News_DJIA.csv", encoding="ISO-8859-1")
df.head(3)
# Out:
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2  2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
#
#                                           Top2  \
# 0      b'BREAKING: Musharraf to be impeached.'
# 1  b'Bush puts foot down on Georgian conflict'
# 2           b"Russia 'ends Georgia operation'"
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# 2  b'"If we had no sexual harassment we would hav...
#
#                                                 Top4  \
# 0  b'Russian tanks are moving towards the capital...
# 1  b'Georgian army flees in disarray as Russians ...
# 2  b"Al-Qa'eda is losing support in Iraq because ...
#
# ...

# %%
df.shape
# Out:
# (1989, 27)

# %%
# rough 80%-20% split into train and test data
train = df[df['Date'] < '20150101'] # ~80% of the data (6 years)
test = df[df['Date'] > '20141231'] # ~20% of the data (2 years)

# %%
# only keep text in data for NLP analysis
data = train.iloc[:, 2:27]
data.replace("[^a-zA-Z]", " ", regex=True, inplace=True)

# Renaming columns to numerical indexes for iteration
indexes = [i for i in range(25)]
new_index_list = [str(i) for i in indexes]
data.columns = new_index_list
data.head(5)
# Out:
#                                                    0  \
# 0  b Georgia  downs two Russian warplanes  as cou...
# 1  b Why wont America and Nato help us  If they w...
# 2  b Remember that adorable   year old who sang a...
# 3  b  U S  refuses Israel weapons to attack Iran ...
# 4  b All the experts admit that we should legalis...
#
#                                                    1  \
# 0            b BREAKING  Musharraf to be impeached
# 1        b Bush puts foot down on Georgian conflict
# 2                 b Russia  ends Georgia operation
# 3  b When the president ordered to attack Tskhinv...
# 4  b War in South Osetia      pictures made by a ...
#
#                                                    2  \
# 0  b Russia Today  Columns of troops roll into So...
# 1  b Jewish Georgian minister  Thanks to Israeli ...
# 2  b  If we had no sexual harassment we would hav...
# 3  b  Israel clears troops who killed Reuters cam...
# 4  b Swedish wrestler Ara Abrahamian throws away ...
#
# ...

# %%
# Converting headlines to lower case.
for index in new_index_list:
    data[index] = data[index].str.lower()
data.head(1)
# Out:
#                                                    0  \
# 0  b georgia  downs two russian warplanes  as cou...
#
#                                          1  \
# 0  b breaking  musharraf to be impeached
#
#                                                    2  \
# 0  b russia today  columns of troops roll into so...
#
#                                                    3  \
# 0  b russian tanks are moving towards the capital...
#
#                                                    4  \
# 0  b afghan children raped with  impunity   u n  ...
#
#                                                    5  \
# 0  b     russian tanks have entered south ossetia...
#
#                                                    6  \
# 0  b breaking  georgia invades south ossetia  rus...
#
#                                                    7  \
# 0  b the  enemy combatent  trials are nothing but...
#
#                                                    8  \
# ...

# %%
# combine into single string, test with row 0
' '.join(str(x) for x in data.iloc[0, 0:25])
# Out:
# 'b georgia  downs two russian warplanes  as countries move to brink of war  b breaking  musharraf to be impeached   b russia today  columns of troops roll into south ossetia  footage from fighting  youtube   b russian tanks are moving towards the capital of south ossetia  which has reportedly been completely destroyed by georgian artillery fire  b afghan children raped with  impunity   u n  official says   this is sick  a three year old was raped and they do nothing  b     russian tanks have entered south ossetia whilst georgia shoots down two russian jets   b breaking  georgia invades south ossetia  russia warned it would intervene on so s side  b the  enemy combatent  trials are nothing but a sham  salim haman has been sentenced to       years  but will be kept longer anyway just because they feel like it   b georgian troops retreat from s  osettain capital  presumably leaving several hundred people killed   video   b did the u s  prep georgia for war with russia   b rice gives gre
# ...

# %%
# list with each row containg all 25 headlines in string (since they are used together to predict)
headlines = []
for rowNum in range(0, len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[rowNum, 0:25]))
headlines[0]
# Out:
# 'b georgia  downs two russian warplanes  as countries move to brink of war  b breaking  musharraf to be impeached   b russia today  columns of troops roll into south ossetia  footage from fighting  youtube   b russian tanks are moving towards the capital of south ossetia  which has reportedly been completely destroyed by georgian artillery fire  b afghan children raped with  impunity   u n  official says   this is sick  a three year old was raped and they do nothing  b     russian tanks have entered south ossetia whilst georgia shoots down two russian jets   b breaking  georgia invades south ossetia  russia warned it would intervene on so s side  b the  enemy combatent  trials are nothing but a sham  salim haman has been sentenced to       years  but will be kept longer anyway just because they feel like it   b georgian troops retreat from s  osettain capital  presumably leaving several hundred people killed   video   b did the u s  prep georgia for war with russia   b rice gives gre
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
# bag of words implementation
# converts each row's headline string intor a list of word counts
# uses word pair (2-grams so ngram range 2,2, i.e. min and max size of 2)
# considers word pairs and not just single words which can improve accuracy
countvector = CountVectorizer(ngram_range=(2,2))
traindataset = countvector.fit_transform(headlines)
traindataset[0]
# Out:
# <1x403977 sparse matrix of type '<class 'numpy.int64'>'
# 	with 342 stored elements in Compressed Sparse Row format>

# %%
# Implement Random Forest using entropy for split (since using information gain)
randomclassifier = RandomForestClassifier(criterion='entropy')
randomclassifier.fit(traindataset, train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
#plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    # heatmap format
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    # tick marks for classes
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    # text coloring threshold (black or white)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
## Predict for the Test Dataset
test_transform = []
for rowNum in range(0, len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[rowNum, 2:27]))
# transform test data into the same format as training data
test_dataset = countvector.transform(test_transform)
predictions = randomclassifier.predict(test_dataset)

# %%
## Import library to check accuracy
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# [[true negative, false positive], [false negative, true positive]]
matrix = confusion_matrix(test['Label'], predictions)
print(matrix)
# classes (stock market DJIA adj close value status): Down = 0, Up (or same) = 1
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[132  54]
#  [  0 192]]

# %%
score = accuracy_score(test['Label'], predictions)
print(round(score*100, 2))
# Out:
# 85.71

# %%
report = classification_report(test['Label'], predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83       186
#            1       0.78      1.00      0.88       192
#
#     accuracy                           0.86       378
#    macro avg       0.89      0.85      0.85       378
# weighted avg       0.89      0.86      0.85       378

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# test model with TF-IDF vectorizer
tfidfvector = TfidfVectorizer(ngram_range=(2,2))
traindataset = tfidfvector.fit_transform(headlines)

randomclassifier = RandomForestClassifier(criterion='entropy')
randomclassifier.fit(traindataset, train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
# Predict for the Test Dataset
test_transform = []
for row in range(0, len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row, 2:27]))
test_dataset = tfidfvector.transform(test_transform)
predictions = randomclassifier.predict(test_dataset)

# %%
matrix = confusion_matrix(test['Label'], predictions)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[151  35]
#  [ 24 168]]

# %%
score = accuracy_score(test['Label'], predictions)
print(round(score*100, 2))
# Out:
# 84.39

# %%
report = classification_report(test['Label'], predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84       186
#            1       0.83      0.88      0.85       192
#
#     accuracy                           0.84       378
#    macro avg       0.85      0.84      0.84       378
# weighted avg       0.84      0.84      0.84       378

# %%
from sklearn.naive_bayes import MultinomialNB

# using Multinomial Naive Bayes classifier since it can be used with word counts in text classification
naive = MultinomialNB()

# %%
# test with bag of words
countvector = CountVectorizer(ngram_range=(2,2))
traindataset = countvector.fit_transform(headlines)
naive.fit(traindataset, train['Label'])
# Out:
# MultinomialNB()

# %%
# Predict for the Test Dataset
test_transform = []
for rowNum in range(0, len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[rowNum, 2:27]))
# transform test data into the same format as training data
test_dataset = countvector.transform(test_transform)
predictions = naive.predict(test_dataset)

# %%
matrix = confusion_matrix(test['Label'], predictions)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[140  46]
#  [ 12 180]]

# %%
score = accuracy_score(test['Label'], predictions)
print(round(score*100, 2))
# Out:
# 84.66

# %%
report = classification_report(test['Label'], predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83       186
#            1       0.80      0.94      0.86       192
#
#     accuracy                           0.85       378
#    macro avg       0.86      0.85      0.84       378
# weighted avg       0.86      0.85      0.85       378

# %%
# test model with TF-IDF vectorizer
tfidfvector = TfidfVectorizer(ngram_range=(2,2))
traindataset = tfidfvector.fit_transform(headlines)

naive.fit(traindataset, train['Label'])
# Out:
# MultinomialNB()

# %%
# Predict for the Test Dataset
test_transform = []
for row in range(0, len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row, 2:27]))
test_dataset = tfidfvector.transform(test_transform)
predictions = naive.predict(test_dataset)

# %%
matrix = confusion_matrix(test['Label'], predictions)
print(matrix)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[130  56]
#  [  0 192]]

# %%
score = accuracy_score(test['Label'], predictions)
print(round(score*100, 2))
# Out:
# 85.19

# %%
report = classification_report(test['Label'], predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82       186
#            1       0.77      1.00      0.87       192
#
#     accuracy                           0.85       378
#    macro avg       0.89      0.85      0.85       378
# weighted avg       0.89      0.85      0.85       378

# %%
# accuracies:

# Random Forest with Bag of Words:  85.71%
# Random Forest with TF-IDF:  84.39%
# Multinomial Naive Bayes with Bag of Words:  84.66%
# Multinomial Naive Bayes with TF-IDF:  85.19%
